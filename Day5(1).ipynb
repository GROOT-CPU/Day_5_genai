# %%
from langchain.prompts import PromptTemplate

# %%
# %pip install --upgrade --quiet langchain-google-genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 3.0 MB/s eta 0:00:00

# %%
from langchain_google_genai import GoogleGenerativeAI

# %%
model=GoogleGenerativeAI(model="gemini-pro",api_key="AIzaSyB_PT_hVIR6SAczkR25D94zmE9ayGv43z8")

# %%
res=model.invoke("write a function to perform a  simple sum of series of n numbers")

# %%
print(res)
# Out:
# ```python
# def sum_of_series(n):
#     """
#     This function calculates the sum of a series of n numbers.
#
#     Args:
#         n (int): The number of terms in the series.
#
#     Returns:
#         int: The sum of the series.
#     """
#
#     # Initialize the sum to 0.
#     sum = 0
#
#     # Iterate over the numbers from 1 to n.
#     for i in range(1, n + 1):
#         # Add the current number to the sum.
#         sum += i
#
#     # Return the sum.
#     return sum
# ```

# %%
demo_template="""write a(language)function to performs sum of seris of n niumbers"""

# %%
prompt=PromptTemplate(input_variables=["language"],template=demo_template)

# %%
prompt.format(language="puthon")
# Out:
# 'write a(language)function to performs sum of seris of n niumbers'

# %%
res=model.invoke("write a java function to perfom sum of seeris of n numbers")

# %%
print(res)
# Out:
# ```java
# import java.util.Scanner;
#
# public class SumOfSeries {
#
#     public static void main(String[] args) {
#         Scanner scanner = new Scanner(System.in);
#
#         // Read the number of terms in the series
#         System.out.println("Enter the number of terms in the series: ");
#         int n = scanner.nextInt();
#
#         // Calculate the sum of the series
#         int sum = 0;
#         for (int i = 1; i <= n; i++) {
#             sum += i;
#         }
#
#         // Print the sum of the series
#         System.out.println("The sum of the series is: " + sum);
#     }
# }
# ```

# %%
prompt_text=prompt.format(programming="python",query="write a function to display the list of evven number")

# %%
res=model.invoke(prompt_text)

# %%
print(res)
# Out:
# ```python
# def sum_of_series(n):
#   """Returns the sum of the series 1 + 2 + ... + n."""
#
#   # Check if n is a positive integer.
#   if not isinstance(n, int) or n <= 0:
#     raise ValueError("n must be a positive integer.")
#
#   # Initialize the sum to 0.
#   sum = 0
#
#   # Add each number from 1 to n to the sum.
#   for i in range(1, n + 1):
#     sum += i
#
#   # Return the sum.
#   return sum
# ```

# %%
ram=prompt.format(programming="java",query="write a function to display the the sumo of the series")

# %%
hai=model.invoke(ram)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8ab1d06046c7> in <cell line: 1>()
# ----> 1 llm_chain=LLMChain(prompt=prompt,llm=model)
#
# NameError: name 'LLMChain' is not defined

# %%
from langchain.chains import LLMChain

# %%
from transformers import pipeline

# %%
import pandas as pd

# %%
data=pd.read_html("https://en.wikipedia.org/wiki/National_Institutes_of_Technology_(India)")

# %%
model=AutoModelForTableQuestionAnswering.from_pretrained(model)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-989a5bb6b26f> in <cell line: 1>()
# ----> 1 model=AutoModelForTableQuestionAnswering.from_pretrained(model)
#
# NameError: name 'AutoModelForTableQuestionAnswering' is not defined

# %%
print(data)
# Out:
# [                    0                                                  1
# 0          Other name                               NIT or NITs (plural)
# 1                Type                         Public Technical Institute
# 2         Established  15 August 2007 (via National Institutes of Tec...
# 3  Parent institution         Ministry of Education, Government of India
# 4              Budget  ₹5,040 crore (US$600 million) (FY2024-25 est.)[1]
# 5            Location                                 32 cities in India
# 6            Language                                            English
# 7             Website                          http://nitcouncil.org.in/,             Region Regional Engineering Colleges (REC)
# 0   Eastern Region             Durgapur and Jamshedpur
# 1   Western Region           Nagpur, Surat, and Bhopal
# 2  Southern Region              Warangal and Surathkal
# ...

# %%
from transformers import AutoTokenizer

# %%
from transfromers import AutoModelForTableQuestionAnswering
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-731cd7465302> in <cell line: 1>()
# ----> 1 from transfromers import AutoModelForTableQuestionAnswering
#
# ModuleNotFoundError: No module named 'transfromers'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
! install transformers
# after installation, you can import it using the following line:
from transformers import AutoModelForTableQuestionAnsweringpip

# %%
tokenizer=AutoTokenizer.from_pretrained("model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0add5436b13> in <cell line: 1>()
# ----> 1 tokenizer=AutoTokenizer.from_pretrained("model")
#
# NameError: name 'AutoTokenizer' is not defined

# %%
# !pip install transformers


from transformers import AutoTokenizer, AutoModelForTableQuestionAnswering


tokenizer = AutoTokenizer.from_pretrained("model")
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_http.py in hf_raise_for_status(response, endpoint_name)
#     405     try:
# --> 406         response.raise_for_status()
#     407     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTableQuestionAnswering

# Replace "model" with a valid model identifier
model_name = "google/tapas-base"  # Example: Using TAPAS model for table question answering

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForTableQuestionAnswering.from_pretrained(model_name)
# Out:
# Some weights of TapasForQuestionAnswering were not initialized from the model checkpoint at google/tapas-base and are newly initialized: ['column_output_bias', 'column_output_weights', 'output_bias', 'output_weights']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
model='google/tapas-large-finetuned-wtq'

# %%
tokenizer=AutoTokenizer.from_pretrained(model)

# %%
import tiktoken

tokenizer = tiktoken.get_encoding('cl100k_base')
def tiktoken_len(text):
    tokens = tokenizer.encode(
    text,
    disallowed_special=()
)
    return len(tokens)
tiktoken.encoding_for_model('gpt-3.5-turbo')

# create the length function
token_counts = []
for page in pages:
    token_counts.append(tiktoken_len(page.page_content))
min_token_count = min(token_counts)
avg_token_count = int(sum(token_counts) / len(token_counts))
max_token_count = max(token_counts)

# print token counts
print(f"Min: {min_token_count}")
print(f"Avg: {avg_token_count}")
print(f"Max: {max_token_count}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-99c7f5c761e9> in <cell line: 1>()
# ----> 1 import tiktoken
#       2
#       3 tokenizer = tiktoken.get_encoding('cl100k_base')
#       4 def tiktoken_len(text):
#       5     tokens = tokenizer.encode(
#
# ModuleNotFoundError: No module named 'tiktoken'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
pip install -U langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 27.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 53.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 28.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.3/49.3 kB 3.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.25
#     Uninstalling langchain-core-0.3.25:
#       Successfully uninstalled langchain-core-0.3.25
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.12
#     Uninstalling langchain-0.3.12:
#       Successfully uninstalled langchain-0.3.12
# ...

# %%
from langchain.document_loaders import PyPDFLoader

# %%
# !pip install pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 298.0/298.0 kB 5.1 MB/s eta 0:00:00
# ...

# %%
Loader=PyPDFLoader("/content/dinosaurs.pdf")

# %%
print(Loader.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-182cccc3ecbd> in <cell line: 1>()
# ----> 1 print(Loader.text)
#
# AttributeError: 'PyPDFLoader' object has no attribute 'text'

# %%
from langchain.document_loaders import PyPDFLoader

Loader = PyPDFLoader("/content/dinosaurs.pdf")

pages = Loader.load()

text = ""
for page in pages:
    text += page.page_content

print(text)
# Out:
# DINOSAURS
# COMPILED BY HOWIE BAUM
# DINOSAURS
# COMPILED BY HOWIE BAUM
# THIS IS THE FIRST OF 3 PAGES THAT HELP TO PUT THE 165 MILLION YEAR REIGN OF
# THE DINOSAURS, IN PERSPECTIVE.
# IT IS A CALENDAR THAT IS DESIGNED SO THAT ALL OF THE TIME, SINCE THE BIG
# BANG HAPPENED – 13.8 BILLION YEAR AGO, UP TO THE
# PRESENT TIME, IS COMPRESSED INTO 1 YEAR.
# First
# Dinosaurs
# Dinosaurs lived for 165 million years !!
# Humans have only existed for  0.004% of
# the age of the Earth !
# periodThe rocks of the Cincinnatian series
# were deposited between
# approximately 451 and 443 million
# years ago, during the Ordovician
# period, when all the land was
# underwater !BASIC DINOSAUR FACTS
# •Dinosaurs are a group of reptiles that have lived
# on Earth for about 165 million years.
# About 60% of dinosaurs ate plants (herbivores)
# and 40% ate meat (carnivores)
# •In 1842, the English naturalist Sir Richard Owen coined
# the term Dinosauria, derived from the Greek deinos,
# ...

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

# %%
# !pip install -U langchain-community # This will install the community package that has the HuggingFaceEmbeddings class for langchain

from langchain.embeddings import HuggingFaceEmbeddings  # Then use HuggingFaceEmbeddings with a 'u' to import the class

# %%
embedding=HuggingFaceEmbeddings()
# Out:
# <ipython-input-16-8b002df105c1>:1: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding=HuggingFaceEmbeddings()
# <ipython-input-16-8b002df105c1>:1: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   embedding=HuggingFaceEmbeddings()
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# ...

# %%
embedding.embed_query("hi young engineers how is genai")
# Out:
# [-0.013013102114200592,
#  -0.021287094801664352,
#  -0.03161142021417618,
#  0.05543346703052521,
#  -0.0013796091079711914,
#  -0.009432967752218246,
#  -0.013644388876855373,
#  0.009893769398331642,
#  -0.010176400654017925,
#  0.011202981695532799,
#  0.008691449649631977,
#  -0.03726595640182495,
#  0.016945872455835342,
#  0.07020068913698196,
#  -0.008255834691226482,
#  -0.003993720281869173,
#  0.028922535479068756,
#  -0.011681417003273964,
#  -0.017153248190879822,
#  -0.03038278967142105,
#  -0.01810801401734352,
#  -0.03347310423851013,
#  -0.03369949385523796,
#  0.04441181570291519,
#  -0.00802940409630537,
#  0.003266773419454694,
#  0.03290252014994621,
#  -0.004468364641070366,
#  0.012241097167134285,
#  -0.0011403757380321622,
#  -0.01701941341161728,
#  0.030861422419548035,
#  -0.04435570165514946,
#  0.06694858521223068,
#  1.461704073335568e-06,
#  0.00404787203297019,
#  0.05302815139293671,
#  0.04001475125551224,
#  0.0053901681676507,
# ...

# %%
pip install faiss-cpu
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.5/27.5 MB 16.0 MB/s eta 0:00:00
# ...

# %%
from langchain.vectorstores import FAISS

# %%
re=FAISS.from_documents(pages,embedding)
